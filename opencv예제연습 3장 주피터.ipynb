# %%
#예제 3.1
import cv2
import numpy as np

#white 배경 생성
img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255
#img = np.ones((512, 512, 3), np.uint8) * 255  #1로 초기화된 배열
#img = np.full((512, 512, 3), (255, 255, 255), dtype = np.uint8) #배경컬러지정
#img = np.zeros((512, 512, 3), np.uint8) #Black 배경
pt1 = 100, 100
pt2 = 400, 400
cv2.rectangle(img, pt1, pt2, (0, 255, 0), 2) #녹색(0, 255, 0)

cv2.line(img, (0,0), (500,0), (255,0,0), 5) #파란색(255, 0, 0)BGR
cv2.line(img, (0,0), (0,500), (0,0,255), 5)

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.2
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경

x1, x2 = 100, 400
y1, y2 = 100, 400
cv2.rectangle(img, (x1, y1), (x2, y2), (0, 0, 255)) 

pt1 = 120, 50
pt2 = 300, 500
cv2.line(img, pt1, pt2, (255,0,0), 2)  #y좌표가 위 기준

imgRect = (x1, y1, x2 - x1, y2 - y1)
retval, rpt1, rpt2 = cv2.clipLine(imgRect, pt1, pt2)
if retval:
    cv2.circle(img, rpt1, radius=5, color= (0, 255, 0),
                thickness= -1)
    cv2.circle(img, rpt2, radius=5, color= (0, 255, 0),
                thickness= -1)

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.3 원그리기
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경
cy = img.shape[0] // 2 # 창의 중심좌표의 높이 / 2
cx = img.shape[1] // 2 # 창의 중심좌표의 넓이 / 2
print(cx, cy)

for r in range(200, 0, -100): # 200부터 0까지 -100간격(r = 200, 100)
    cv2.circle(img, (cx, cy), r, color = (255, 0, 0))

cv2.circle(img, (cx, cy), radius= 50, color= (0, 0, 255),
           thickness = -1) 

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.4 타원 그리기
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경
ptCenter = img.shape[1] // 2, img.shape[0] // 2
size = 200, 100

cv2.ellipse(img, ptCenter, size, 0, 0, 360, (255, 0, 0,))
cv2.ellipse(img, ptCenter, size, 45, 0, 360, (0, 0, 255,))

# 사각형의 내부에서 타원 그리기
# box: (중심점, 크기(x, y), 기울기) 회전 사각형
box = (ptCenter, size, 0)
cv2.ellipse(img, box, (255, 0, 0), 5)

box = (ptCenter, size, 45)
cv2.ellipse(img, box, (0, 0, 255), 5)

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.5 다각형 그리기 1
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경
pts1 = np.array([[100, 100], [200, 100], [200, 200], [100,200]])
pts2 = np.array([[300, 200], [400, 100], [400, 200]])

cv2.polylines(img, [pts1, pts2], isClosed= True,
              color= (255, 0, 0))

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.6 다각형 그리기 2
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경

ptCenter = img.shape[1] // 2, img.shape[0] // 2
size = 200, 100

cv2.ellipse(img, ptCenter, size, 0, 0, 360, (255, 0, 0))
pts1 = cv2.ellipse2Poly(ptCenter, size, 0, 0, 360, delta = 40)

cv2.ellipse(img, ptCenter, size, 45, 0, 360, (255, 0, 0))
pts2 = cv2.ellipse2Poly(ptCenter, size, 45, 0, 360, delta = 45)
cv2.polylines(img, [pts1, pts2], isClosed= True,
              color= (0, 0, 255))

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.7 다각형 그리기 3
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경

x, y = 256, 256
size = 200

for angle in range(0, 90, 10):
    rect = ((256, 256), (size, size), angle)
    box = cv2.boxPoints(rect).astype(np.int32)
    r = np.random.randint(256)
    g = np.random.randint(256)
    b = np.random.randint(256)
    cv2.polylines(img, [box], True, (b, g, r), 2)

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.8 다각형 채우기
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경

pts1 = np.array([[100, 100], [200, 100], [200, 200], [100,200]])
pts2 = np.array([[300, 200], [400, 100], [400, 200]])

cv2.fillConvexPoly(img, pts1, color= (255, 0, 0))  #블록다각형 채우기

cv2.fillPoly(img, [pts2], color= (0, 0, 255))  #다각형 채우기
#cv2.fillPoly(img, [pts1], [pts2], color = (0, 0, 255))

cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.9 문자열 출력
import cv2
import numpy as np

img = np.zeros(shape = (512, 512, 3), dtype = np.uint8) + 255 #white 배경
text = 'OpenCV Programming'
org = (50, 100)
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,text, org, font, 1, (255, 0, 0), 2)

size, baseLine = cv2.getTextSize(text, font, 1, 2)
print('size', size)
print('baselLine=', baseLine) #사각형 아래 기준선의 상대적인 y값
cv2.rectangle(img, org, (org[0] + size[0], org[1] - size[1]),
                (0, 0, 255))
cv2.circle(img, org, 3, (0, 255, 0), 2)
#print(org[0] + size[0],org[1] - size[1])
cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.10 키보드 이벤트 처리
import numpy as np
import cv2

width, height = 512, 512
x, y, R = 256, 256, 50
direction = 0                           #right

while True:
    key = cv2.waitKeyEx(30)
    if key == 0x1B:
        break;

# 방향키 방향전환
    elif key == 0x270000:       #right
        direction = 0
    elif key == 0x280000:       #down
        direction = 1           
    elif key == 0x250000:       #left
        direction = 2
    elif key == 0x260000:       #up
        direction = 3

# 방향으로 이동
    if direction == 0:          #right
        x += 10
    elif direction == 1:        #down
        y += 10
    elif direction == 2:        #left
        x -= 10
    else: # 3, up
        y -= 10

# 경계확인
    if x < R:
        X = R
        direction = 0
    if x > width - R:
        x = width - R
        direction = 2
    if y < R:
        y = R
        direction = 1
    if y > height - R:
        y = height - R
        direction = 3

# 지우고, 그리기
    img = np.zeros((width, height, 3), np.uint8) + 255  #지우기
    cv2.circle(img, (x,y), R, (0,0,255), -1)
    cv2.imshow('img', img)

cv2.destroyAllWindows()

# %%
#예제 3.11 마우스 이벤트 처리
import numpy as np
import cv2

def onMouse(event, x, y, flags, param):
##   global img
    if event == cv2.EVENT_LBUTTONDOWN:       #마우스 왼쪽 버튼 클릭
        if flags & cv2.EVENT_FLAG_SHIFTKEY:   #Shift 키와 함께
            cv2.rectangle(param[0], (x - 5, y - 5),
                                    (x + 5, y + 5), (255, 0, 0))
        else:
            cv2.circle(param[0], (x,y), 5, (255, 0, 0), 3)
    elif event == cv2.EVENT_RBUTTONDOWN:      #마우스 오른쪽 버튼 클릭
        cv2.circle(param[0], (x, y), 5, (0, 0, 255), 3)
    elif event == cv2.EVENT_LBUTTONDBLCLK:    #마우스 왼쪽 버튼 클릭
        param[0] = np.zeros(param[0].shape, np.uint8) + 255
    cv2.imshow("img", param[0])

img = np.zeros((512, 512, 3), np.uint8) + 255  #지우기
cv2.imshow('img', img)
cv2.setMouseCallback('img', onMouse, [img])
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#예제 3.12 트랙바 이벤트 처리
import cv2
import numpy as np

def onChange(pos):              # 트랙바 핸들러
    global img
    r = cv2.getTrackbarPos('R', 'img')
    g = cv2.getTrackbarPos('G', 'img')
    b = cv2.getTrackbarPos('B', 'img')
    img[:] = (b,g,r)
    cv2.imshow('img', img)

img = np.zeros((512, 512, 3), np.uint8)
cv2.imshow('img', img)

# 트랙바 생성
cv2.createTrackbar('R', 'img', 0, 255, onChange)
cv2.createTrackbar('G', 'img', 0, 255, onChange)
cv2.createTrackbar('B', 'img', 0, 255, onChange)

# 트랙바의 위치 초기화
#cv2.setTrackbarPos('B', 'img', 0)
#cv2.setTrackbarPos('G', 'img', 0)
cv2.setTrackbarPos('B', 'img', 255)

cv2.waitKey()
cv2.destroyAllWindows()
